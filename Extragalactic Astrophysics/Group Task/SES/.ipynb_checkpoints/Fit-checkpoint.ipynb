# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

X = pd.read_csv('chis.dat', sep=" ",header=None)
X.columns=['alpha','chi']

alpha = np.array(X["alpha"])
chi = np.array(X["chi"])

plt.plot(alpha,chi,linewidth=0,markersize=2,marker='o')
