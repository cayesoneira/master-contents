# %% [markdown]
# # R-class 4 (2 hours)
#
# ## Exercise 2

# %% [markdown]
# - 1. Plot the data (including error bars, assuming Poisson statistics), rebin them in weekly number of cases
# - 2. Concentrating on t=650 to 740 days after 1 January 2020, and defining $t'(t_{0} )=\max(0,t-t_{0} )$:
#     - a. Model the evolution of daily cases as a constant plus a power evolution in t'. First assume a constant (a=0), then a constant plus a single power with a=1, then a single power with a=2, then a combination of two powerlaws with a=1 and b=2 and with different values of t0, and finally a combination with free exponents.
#     - b. Make sure to answer the following two questions in your report:
#         - Which of them is the best model? Why?
#         - When did the corresponding wave start? Why?
#     - c. Optional for extra score: plot Δχ 2 contours on (a,b) for the model with free exponents. What can you conclude from them?

# %% [markdown]
# 1) DATA: isciii_Cantabria_code01.csv
# - 1.0 Read data (Poiss errors - sqrt): days_since_01012022, number_of_cases

# %%
library(Hmisc)

dat <- read.csv("isciii_Cantabria_code01.csv")
# head(dat)

# %% [markdown]
# - 1.1 Plot data

# %%
options(repr.plot.width=6,repr.plot.height=6)
errbar(dat[,1],dat[,2],dat[,2]+sqrt(dat[,2]),dat[,2]-sqrt(dat[,2]))
# Out:
# plot without title

# %% [markdown]
# - 1.2 rebin in 7 days blocks (0-6, 7-13, ...)

# %%
x <- c()
y <- c()
sdy <- c()
n <- length(dat[,2])

for (i in seq(1,n,by=7)){
    # cat("i=",i,"\n")
    # cat(sum(dat[,2][i-1:i+7]),"\n")
    j <- i+6
    y <- c(y,sum(dat[,2][i:j])/7)
    # Assuming Poisson in the number of cases per day, the deviation is the sqrt of the values
    sdy <- c(sdy, sqrt( sum( dat[,2][i:i+7] ) )/7 )
    x <- c(x,i+3)
}

errbar(x,y,y+sdy,y-sdy)
# Out:
# i= 1
# 0
# i= 8
# 0
# i= 15
# 0
# i= 22
# 0
# i= 29
# 0
# i= 36
# 0
# i= 43
# 0
# i= 50
# 10
# i= 57
# 12
# i= 64
# 62
# i= 71
# 443
# i= 78
# 1182
# i= 85
# 1518
# i= 92
# 1805
# i= 99
# 2003
# i= 106
# 2127
# i= 113
# 2217
# i= 120
# 2254
# i= 127
# 2280
# i= 134
# 2296
# i= 141
# 2310
# i= 148
# 2325
# i= 155
# 2331
# i= 162
# 2344
# i= 169
# 2360
# i= 176
# 2368
# i= 183
# 2375
# i= 190
# 2386
# i= 197
# 2428
# i= 204
# 2475
# i= 211
# 2676
# i= 218
# 2974
# i= 225
# 3390
# i= 232
# 3908
# i= 239
# 4677
# i= 246
# 5452
# i= 253
# 6111
# i= 260
# 6598
# i= 267
# 6923
# i= 274
# 7258
# i= 281
# 7730
# i= 288
# 8690
# i= 295
# 9857
# i= 302
# 11328
# i= 309
# 12892
# i= 316
# 14263
# i= 323
# 15104
# i= 330
# 15855
# i= 337
# 16534
# i= 344
# 17038
# i= 351
# 17476
# i= 358
# 18071
# i= 365
# 18930
# i= 372
# 20016
# i= 379
# 21149
# i= 386
# 22295
# i= 393
# 23156
# i= 400
# 23781
# i= 407
# 24275
# i= 414
# 24653
# i= 421
# 24964
# i= 428
# 25218
# i= 435
# 25503
# i= 442
# 25832
# i= 449
# 26228
# i= 456
# 26692
# i= 463
# 27274
# i= 470
# 28050
# i= 477
# 28764
# i= 484
# 29373
# i= 491
# 29716
# [57,] 788  186.14286
# [58,] 795  166.85714
# [59,] 802  169.00000
# [60,] 809  169.57143
# [61,] 816   97.42857

# %% [markdown]
# - 1.3 plot binned interval from 650 to 740 days

# %%
aa <- round(650/7); bb <- round(740/7)
xm <- x[aa:bb]
ym <- y[aa:bb]
sdym <- sdy[aa:bb]

write(xm, "x.txt")
write(ym, "y.txt")
errbar(xm, ym, ym+sdym, ym-sdym)
# Out:
# plot without title

# %% [markdown]
# 2) Fitting (plot fittings) + Chi2 calculations + Goodness of fit
#
#     Q = pH0 = pchisq(chi2>chi2_of_fit)
#
# - 2.1) Fit model "constant", Chi2 & P(H0) => use 'lm'

# %% [markdown]
# ### *Constant* (1 parameter) $$N_{0}$$

# %%
fit_lm <- lm(ym ~ 1)
fit_lm

plot(xm,ym)
abline(fit_lm, col="blue", lwd=2)
# Out:
# Call:
# lm(formula = ym ~ 1)
#
# Coefficients:
# (Intercept)
#       63.28
# plot without title

# %% [markdown]
# - 2.2) Fit model "coli": constant + linear using Chi2 & P(H0) => use 'optim' with initial values:
# N0 = N0/2
# t0 = 700
# tau = 0.01

# %% [markdown]
# ### *Coli* (3 parameters) $$N_0 + \frac{max(0,(x-t_0))}{\tau}$$

# %%
fun.to.fit <- function(x, n0, t0, tau){
    n0 + ifelse(x-t0<0,0,x-t0)/tau
}

fun.to.minimize <- function(coefs,x,y){
    n0 <- coefs[1]
    t0 <- coefs[2]
    tau <- coefs[3]
    
    out <- sum( ((y-fun.to.fit(x,n0, t0, tau))/sdym)**2)
}

# N0 obtained for the previous fit
n00 <- 220
t00 <- 700
tau0 <- 0.01
fit_optim <- optim(c(n00,t00,tau0), fun.to.minimize, x=xm, y=ym)
fit_optim$par

afit <- fit_optim$par[1]
bfit <- fit_optim$par[2]
cfit <- fit_optim$par[3]

chi_coli <- sum((ym-fun.to.fit(xm,afit,bfit,cfit))**2/sdym**2)
chi_coli

plot(xm,ym)
points(xm,fun.to.fit(xm,afit,bfit,cfit), col='blue',lty=2)
curve(fun.to.fit(x,afit,bfit,cfit), add = TRUE, col='blue',lty=2)
legend("topleft", c("OPTIM", "LM"), lty=c(2,6), col=c("blue","red"), cex=0.8, bty='n')
# Out:
# [1]   6.159193 878.180816  59.522858
# [1] 5594.805
# plot without title

# %% [markdown]
# - 2.3) Fit model "coliqua": constant + linear +  power(2) using Chi2 & P(H0) => use 'optim' with initial values:
#     N0.init <- N0_coli
#     t01.init <- 713 # very sensitive to this value
#     tau1.init <- tau_coli
#     t02.init <- t0_coli
#     tau2.init <- 3  (not less than 3)

# %% [markdown]
# ### *Coliqua* (5 parameters) $$N_0 + \frac{max(0,(x-t_{01}))}{\tau_1} + \left(\frac{max(0,(x-t_{02}))}{\tau_2}\right)^2$$

# %%
fun.to.fit <- function(x, n0, t01, tau1, t02, tau2){
    n0 + ifelse(x-t01<0,0,x-t01)/tau1 + (ifelse(x-t02<0,0,x-t02)/tau2)**2
    # y <- n0 + replace(x, x-t0 < 0, 0)/tau
    # return(y)
}

fun.to.minimize <- function(coefs,x,y){
    n0 <- coefs[1]
    t01 <- coefs[2]
    tau1 <- coefs[3]
    t02 <- coefs[4]
    tau2 <- coefs[5]
    
    out <- sum((y-fun.to.fit(x,n0, t01,tau1, t02, tau2))**2/sdym**2)
}

# N0 obtained for the previous fit
n00 <- 200
t010 <- 713 # Very sensitive to this value
tau10 <- 0.01
t020 <- 700
tau20 <- 3.1

fit_optim <- optim(c(n00,t010,tau10,t020,tau20), fun.to.minimize, x=xm, y=ym)
fit_optim$par

afit <- fit_optim$par[1]
bfit <- fit_optim$par[2]
cfit <- fit_optim$par[3]
dfit <- fit_optim$par[4]
efit <- fit_optim$par[5]

chi_coliqua <- sum((ym-fun.to.fit(xm,afit,bfit,cfit,dfit,efit))**2/sdym**2)
chi_coliqua

plot(xm,ym)
points(xm,fun.to.fit(xm,afit,bfit,cfit,dfit,efit), col='blue',lty=2)
curve(fun.to.fit(x,afit,bfit,cfit,dfit,efit), add = TRUE, col='blue',lty=2)
legend("topleft", c("OPTIM", "LM"), lty=c(2,6), col=c("blue","red"), cex=0.8, bty='n')
# Out:
# [1]   6.20672 804.62719  66.87808 753.92776  38.51603
# [1] 5594.801
# plot without title

# %% [markdown]
# - 2.4) Fit model "copopo": constant + power(a) + power(b) using Chi2 & P(H0) => use 'optim' with initial values:
#     N0.init <- N0_coliqua
#     t01.init <- t01_coliqua
#     tau1.init <- tau1_coliqua
#     a.init <- 1
#     t02.init <- t02_coliqua
#     tau2.init <- tau2_coliqua
#     b.init <- 2

# %% [markdown]
# ### *Cocopo* (7 parameters) $$ N_0 + \left(\frac{max(0,(x-t_{01})}{\tau_1}\right)^a + \left(\frac{max(0,(x-t_{02}))}{\tau_2}\right)^b $$

# %%
fun.to.fit <- function(x, n0, t01, tau1, t02, tau2, a, b){
    n0 + (ifelse(x-t01<0,0,x-t01)/tau1)**a + (ifelse(x-t02<0,0,x-t02)/tau2)**b
    # y <- n0 + replace(x, x-t0 < 0, 0)/tau
    # return(y)
}

fun.to.minimize <- function(coefs,x,y){
    n0 <- coefs[1]
    t01 <- coefs[2]
    tau1 <- coefs[3]
    t02 <- coefs[4]
    tau2 <- coefs[5]
    a <- coefs[6]
    b <- coefs[7]
    
    out <- sum((y-fun.to.fit(x, n0, t01, tau1, t02, tau2, a, b))**2/sdym**2)
}

# N0 obtained for the previous fit
n00 <- 200
# 700 days are 100 weeks
t010 <- 713
tau10 <- 0.01
t020 <- 700
tau20 <- 3.1
a0 <- 1
b0 <- 2

fit_optim <- optim(c(n00,t010,tau10,t020,tau20, a0, b0), fun.to.minimize, x=xm, y=ym)
fit_optim$par

afit <- fit_optim$par[1]
bfit <- fit_optim$par[2]
cfit <- fit_optim$par[3]
dfit <- fit_optim$par[4]
efit <- fit_optim$par[5]
ffit <- fit_optim$par[6]
gfit <- fit_optim$par[7]

chi_cocopo <- sum((ym-fun.to.fit(xm,afit,bfit,cfit,dfit,efit,ffit,gfit))**2/sdym**2)
chi_cocopo

plot(xm,ym)
points(xm,fun.to.fit(xm,afit,bfit,cfit,dfit,efit,ffit,gfit), col='blue',lty=2)
curve(fun.to.fit(x,afit,bfit,cfit,dfit,efit,ffit,gfit), add = TRUE, col='blue',lty=2)
legend("topleft", c("OPTIM", "LM"), lty=c(2,6), col=c("blue","red"), cex=0.8, bty='n')
# Out:
# [1] 6.167499e+00 7.622859e+02 2.927531e+01 7.259160e+02 4.542229e+01
# [6] 6.841906e+01 6.227534e-04
# [1] 5567.55
# plot without title

# %% [markdown]
# 3) Calculate Ftest for EACH model comparison (do not confuse with var.test): "coli" vs "co"; "coliqua" vs "coli"; "copopo" vs "coliqua"
#
# Calculate F (from class expressions and then calculate the probability of F being larger that this value):
#         Ex.:
#         F_co_coli = (see class notes expression)
#         pf(F>F_co_coli, ...), nu1=nu_co-nu_coli; nu2=nu_coli
#         improve=1-pF

# %% [markdown]
# "coli" vs "co"

# %% [markdown]
# "coliqua" vs "coli"

# %% [markdown]
# "copopo" vs "coliqua"

# %% [markdown]
# 4) OPTIONAL: confidence contours for "a" and "b" in model "copopo"
#
#     define a grid in 'a' and 'b'
#     foreach 'a':
#        foreach 'b':
#            minimize with 'optim' to all the other params (except 'a' and 'b') with initial values those
#            of previous copopo fit
#            save chi2
#     matrix of chi2 values
#     call R command 'contour'
#
#     Notes: very sensitive to initial values in optim for each (a,b) tested values; not very well behaved function

# %%
ch <- matrix(,nrow = 1000, ncol = 1000)
i <- 1
j <- 1

arange <- seq(0.5,1.5,by=0.1)
brange <- seq(1.5,2.5,by=0.1)

for (a in arange){
    i <- 1
    for (b in brange){
        fun.to.fit <- function(x, n0, t01, tau1, t02, tau2){
        n0 + (ifelse(x-t01<0,0,x-t01)/tau1)**a + (ifelse(x-t02<0,0,x-t02)/tau2)**b
        }

        fun.to.minimize <- function(coefs,x,y){
            n0 <- coefs[1]
            t01 <- coefs[2]
            tau1 <- coefs[3]
            t02 <- coefs[4]
            tau2 <- coefs[5]
            
            sdy <- sqrt(y)
            
            out <- sum((y-fun.to.fit(x,n0, t01,tau1, t02, tau2))**2/sdy**2)
        }

        # N0 obtained for the previous fit
        #n00 <- fit_optim$par[1]
        #t010 <- fit_optim$par[2]
        #tau10 <- fit_optim$par[3]
        #t020 <- fit_optim$par[4]
        #tau20 <- fit_optim$par[5]
        
        n00 <- 220
        t010 <- 713
        tau10 <- 0.01
        t020 <- 700
        tau20 <- 3

        fit_optim <- optim(c(n00,t010,tau10,t020,tau20), fun.to.minimize, x=xm, y=ym)

        afit <- fit_optim$par[1]
        bfit <- fit_optim$par[2]
        cfit <- fit_optim$par[3]
        dfit <- fit_optim$par[4]
        efit <- fit_optim$par[5]
        
        ch[i,j] <- sum((ym-fun.to.fit(xm,afit,bfit,cfit,dfit,efit))**2/sdym**2)
        i <- i+1
        }
    j <- j+1
}

# %%
contour(arange,brange,ch[1:length(arange),1:length(brange)])
# Out:
# plot without title

# %% [markdown]
# 5) Which is the most apropriate model?

# %% [markdown]
# ### Bibliography
# - [Binning](https://stackoverflow.com/questions/32292542/binning-values-in-a-vector)
# - [Functions](https://swcarpentry.github.io/r-novice-inflammation/02-func-R/)
# - [Replacing](https://www.digitalocean.com/community/tutorials/replace-in-r)
# - [Poisson](https://www.statlect.com/fundamentals-of-statistics/Poisson-distribution-maximum-likelihood)
# - [Errorbars in Hmisc](https://rdrr.io/cran/Hmisc/man/errbar.html)
# - [F test](https://stats.libretexts.org/Bookshelves/Applied_Statistics/Book%3A_Learning_Statistics_with_R_-_A_tutorial_for_Psychology_Students_and_other_Beginners_(Navarro)/16%3A_Factorial_ANOVA/16.05%3A_The___F___test_as_a_model_comparison)
# - [Contour](https://r-charts.com/es/correlacion/contour/)
